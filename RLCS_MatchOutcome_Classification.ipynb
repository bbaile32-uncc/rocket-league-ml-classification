# %%
# Install Parquet Support
# !conda install -y pyarrow
# Out:
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Brandon\anaconda3
#
#   added / updated specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-19.0.0           |       h82e8c66_4         7.6 MB
#     aws-c-auth-0.9.0           |       h827c3e9_1         122 KB
#     aws-c-cal-0.9.2            |       h827c3e9_0          57 KB
#     aws-c-common-0.12.3        |       h827c3e9_0         259 KB
#     aws-c-compression-0.3.1    |       h827c3e9_1          32 KB
#     aws-c-event-stream-0.5.5   |       h827c3e9_0          64 KB
#     aws-c-http-0.10.2          |       h827c3e9_0         215 KB
#     aws-c-io-0.20.1            |       h827c3e9_0         187 KB
#     aws-c-mqtt-0.13.2          |       h827c3e9_0         215 KB
# ...
